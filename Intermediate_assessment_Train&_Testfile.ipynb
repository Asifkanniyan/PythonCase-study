# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv('/content/train_LZdllcl.csv')
test=pd.read_csv('/content/test_2umaH9m.csv')

# %%
train.head(2)
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
#
#    is_promoted
# 0            0
# 1            0

# %%
train.tail(2)
# Out:
#        employee_id         department     region   education gender  \
# 54806        13614  Sales & Marketing   region_9         NaN      m
# 54807        51526                 HR  region_22  Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 54806                  2              0            0                  45
# 54807                  5              0            0                  49
#
#        is_promoted
# 54806            0
# 54807            0

# %%
test.head(2)
# Out:
#    employee_id  department     region   education gender recruitment_channel  \
# 0         8724  Technology  region_26  Bachelor's      m            sourcing
# 1        74430          HR   region_4  Bachelor's      f               other
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   24                   NaN                  1
# 1                1   31                   3.0                  5
#
#    KPIs_met >80%  awards_won?  avg_training_score
# 0              1            0                  77
# 1              0            0                  51

# %%
test.tail(2)
# Out:
#        employee_id   department     region         education gender  \
# 23488         1186  Procurement  region_31        Bachelor's      m
# 23489         5973   Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 23488            sourcing                3   27                   NaN
# 23489               other                3   40                   5.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 23488                  1              0            0                  70
# 23489                  5              1            0                  89

# %%
train.shape
# Out:
# (54808, 14)

# %%
test.shape
# Out:
# (23490, 13)

# %%
train.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# KPIs_met >80%             int64
# awards_won?               int64
# avg_training_score        int64
# is_promoted               int64
# dtype: object

# %%
test.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# KPIs_met >80%             int64
# awards_won?               int64
# avg_training_score        int64
# dtype: object

# %%
train.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
test.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  23490.000000     23490.000000  23490.000000          21678.000000
# mean   39041.399149         1.254236     34.782929              3.339146
# std    22640.809201         0.600910      7.679492              1.263294
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19370.250000         1.000000     29.000000              3.000000
# 50%    38963.500000         1.000000     33.000000              3.000000
# 75%    58690.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score
# count       23490.000000   23490.000000  23490.000000        23490.000000
# mean            5.810387       0.358834      0.022776           63.263133
# std             4.207917       0.479668      0.149191           13.411750
# ...

# %%
train.nunique()
# Out:
# employee_id             54808
# department                  9
# region                     34
# education                   3
# gender                      2
# recruitment_channel         3
# no_of_trainings            10
# age                        41
# previous_year_rating        5
# length_of_service          35
# KPIs_met >80%               2
# awards_won?                 2
# avg_training_score         61
# is_promoted                 2
# dtype: int64

# %%
train['recruitment_channel'].unique()
# Out:
# array(['sourcing', 'other', 'referred'], dtype=object)

# %%
train.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
#Missing value handling

# %%
train['education'].fillna(train['education'].mode()[0],inplace=True)

# %%
train['previous_year_rating'].fillna(train['previous_year_rating'].mode()[0],inplace=True)

# %%
test['education'].fillna(test['education'].mode()[0],inplace=True)

# %%
test['previous_year_rating'].fillna(test['previous_year_rating'].mode()[0],inplace=True)

# %%
plt.figure(figsize=(12,8))
sns.distplot(train['no_of_trainings'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(train['age'],color='r')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(train['KPIs_met >80%'],color='g')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(train['avg_training_score'],color='y')
plt.show()

# %%
fig, axarr = plt.subplots(8, 1, figsize=(15, 15))

sns.boxplot(train['employee_id'],palette='Set1',ax=axarr[0])
sns.boxplot(train['no_of_trainings'],palette='Set2',ax=axarr[1])
sns.boxplot(train['age'],palette='Set3',ax=axarr[2])
sns.boxplot(train['previous_year_rating'],palette='icefire',ax=axarr[3])
sns.boxplot(train['length_of_service'],palette='Dark2',ax=axarr[4])
sns.boxplot(train['KPIs_met >80%'],palette='Set1',ax=axarr[5])
sns.boxplot(train['awards_won?'],palette='plasma',ax=axarr[6])
sns.boxplot(train['avg_training_score'],palette='Set1',ax=axarr[7])
plt.show()

# %%
sns.boxplot(train['age'])
# Out:
# <Axes: ylabel='age'>

# %%
train1=train.copy()
test1=test.copy()

# %%
from sklearn.impute import SimpleImputer

# %%
imp=SimpleImputer(strategy='median')

# %%
train1['previous_year_rating']=imp.fit_transform(train1[['previous_year_rating']])

# %%
imp1=SimpleImputer(strategy='most_frequent')

# %%
train1['education']=imp1.fit_transform(train1[['education']])[:,0]

# %%
##Perform test data

# %%
test1['previous_year_rating']=imp.fit_transform(test1[['previous_year_rating']])

# %%
test1['education']=imp1.fit_transform(test1[['education']])[:,0]

# %%
sns.jointplot(y='avg_training_score',x='age',data=train1,color='y')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['region'],hue=train['is_promoted'],palette='Set1')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='department',hue='is_promoted',data = train1,palette='plasma')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['education'],hue=train['is_promoted'],palette='Set3')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=train1['gender'],hue=train['is_promoted'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['recruitment_channel'],hue=train1['is_promoted'],palette='YlOrRd_r')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['age'],hue=train1['is_promoted'],palette='husl')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['KPIs_met >80%'],hue=train1['is_promoted'],palette='Paired')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['previous_year_rating'],hue=train1['is_promoted'],palette='Set2')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['awards_won?'],hue=train1['is_promoted'],palette='Set1')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['avg_training_score'],hue=train1['is_promoted'],palette='RdGy')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['age'],hue=train1['department'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['education'],hue=train1['department'])
plt.show()

# %%
## more bachelor degree holders

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=train1['recruitment_channel'],hue=train1['department'])
plt.show()

# %%
##more recruitment from other recruitment channel

# %%
sns.countplot(train1['is_promoted'])
plt.show()

# %%
sns.heatmap(train1.select_dtypes(include=np.number).corr())
plt.show()

# %%
ntrain=train1.drop('employee_id', axis=1)
ntest=test1.drop('employee_id', axis=1)

# %%
ntrain.head()
# Out:
#           department     region         education gender recruitment_channel  \
# 0  Sales & Marketing   region_7  Master's & above      f            sourcing
# 1         Operations  region_22        Bachelor's      m               other
# 2  Sales & Marketing  region_19        Bachelor's      m            sourcing
# 3  Sales & Marketing  region_23        Bachelor's      m               other
# 4         Technology  region_26        Bachelor's      m               other
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
x=ntrain.drop('is_promoted',axis=1)
y=ntrain.is_promoted

# %%
x=pd.get_dummies(x)

# %%
test_var=pd.get_dummies(ntest)

# %%
lg=LogisticRegression()

# %%
lg.fit(x,y)
pred=lg.predict(test_var)

# %%
from sklearn.metrics import f1_score,recall_score,accuracy_score,confusion_matrix

# %%
f1_score(y,lg.predict(x))
# Out:
# 0.28651778329197686

# %%
recall_score(y,lg.predict(x))
# Out:
# 0.18551842330762638

# %%
accuracy_score(y,lg.predict(x))
# Out:
# 0.921307108451321

# %%
confusion_matrix(y,lg.predict(x))
# Out:
# array([[49629,   511],
#        [ 3802,   866]])
